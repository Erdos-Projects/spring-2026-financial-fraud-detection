# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/elliptic_bitcoin_data/elliptic_bitcoin_dataset/elliptic_txs_features.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of         230425980   1  -0.1714692896288031  -0.18466755143291433  \
# 0         5530458   1            -0.171484             -0.184668
# 1       232022460   1            -0.172107             -0.184668
# 2       232438397   1             0.163054              1.963790
# 3       230460314   1             1.011523             -0.081127
# 4       230459870   1             0.961040             -0.081127
# ...           ...  ..                  ...                   ...
# 203763  173077460  49            -0.145771             -0.163752
# 203764  158577750  49            -0.165920             -0.123607
# 203765  158375402  49            -0.172014             -0.078182
# 203766  158654197  49            -0.172842             -0.176622
# 203767  157597225  49            -0.012037             -0.132276
#
#         -1.2013688016765636  -0.12196959975910057  -0.04387454791734898  \
# 0                 -1.201369             -0.121970             -0.043875
# ...

# %%
df.loc[0]
# Out:
# 230425980               5.530458e+06
# 1                       1.000000e+00
# -0.1714692896288031    -1.714842e-01
# -0.18466755143291433   -1.846676e-01
# -1.2013688016765636    -1.201369e+00
#                             ...
# -0.0874901561101501    -8.749016e-02
# -0.13115530389558736   -1.311553e-01
# -0.09752359377152515   -9.752359e-02
# -0.12061340670311574   -1.206134e-01
# -0.11979245961251665   -1.197925e-01
# Name: 0, Length: 167, dtype: float64

# %%
classes = pd.read_csv('../data/raw/elliptic_bitcoin_data/elliptic_bitcoin_dataset/elliptic_txs_classes.csv')

# %%
classes.txId
# Out:
# 0         230425980
# 1           5530458
# 2         232022460
# 3         232438397
# 4         230460314
#             ...
# 203764    173077460
# 203765    158577750
# 203766    158375402
# 203767    158654197
# 203768    157597225
# Name: txId, Length: 203769, dtype: int64

# %%
# Check if classes.txId matches the first column of df
first_col = df.iloc[:, 0]
print("Same length:", len(classes.txId) == len(first_col))
print("Same order and values:", classes.txId.equals(first_col))
print("Same set of values:", set(classes.txId) == set(first_col))
# Show any mismatch in order (first few rows)
print("\nFirst 5 values comparison:")
print(pd.DataFrame({"classes.txId": classes.txId.head(), "df first col": first_col.head()}))

# %%
edgelist = pd.read_csv('../data/raw/elliptic_bitcoin_data/elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv')

# %%
edgelist.info
# Out:
# <bound method DataFrame.info of             txId1      txId2
# 0       230425980    5530458
# 1       232022460  232438397
# 2       230460314  230459870
# 3       230333930  230595899
# 4       232013274  232029206
# ...           ...        ...
# 234350  158365409  157930723
# 234351  188708874  188708879
# 234352  157659064  157659046
# 234353   87414554  106877725
# 234354  158589452  158589457
#
# [234355 rows x 2 columns]>

# %%
df.txId
# Out:
# 0           5530458
# 1         232022460
# 2         232438397
# 3         230460314
# 4         230459870
#             ...
# 203763    173077460
# 203764    158577750
# 203765    158375402
# 203766    158654197
# 203767    157597225
# Name: txId, Length: 203768, dtype: int64
